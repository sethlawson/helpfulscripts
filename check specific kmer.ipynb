# %%
import pandas as pd
import re

kmer_to_investigate = 'AAUU'

#fastalist = open(r'C:\Users\lawsonsa\Documents\fastalist.txt', 'r')
fastalist = open(r"C:\Users\lawsonsa\Documents\mature human miRNAs.fa.txt", 'r')
lines = fastalist.readlines()

for i in lines:
    if kmer_to_investigate in i:
        print(lines[lines.index(i)-1][1:])
# Out:
# hsa-miR-25-5p
#
# hsa-miR-26b-5p
#
# hsa-miR-32-3p
#
# hsa-miR-95-5p
#
# hsa-miR-192-5p
#
# hsa-miR-192-3p
#
# hsa-miR-10a-5p
#
# hsa-miR-10a-3p
#
# hsa-miR-10b-5p
#
# hsa-miR-183-5p
#
# hsa-miR-183-3p
#
# hsa-miR-215-5p
#
# hsa-miR-219a-5p
#
# hsa-miR-146a-5p
#
# hsa-miR-146a-3p
#
# hsa-miR-186-5p
#
# hsa-miR-186-3p
#
# hsa-miR-219a-2-3p
#
# hsa-miR-363-5p
#
# hsa-miR-363-3p
#
# hsa-miR-367-3p
#
# hsa-miR-376c-3p
#
# hsa-miR-374a-3p
#
# hsa-miR-377-5p
#
# hsa-miR-384
#
# hsa-miR-424-5p
#
# hsa-miR-485-5p
#
# hsa-miR-146b-5p
#
# hsa-miR-513a-3p
#
# hsa-miR-539-5p
#
# hsa-miR-539-3p
#
# hsa-miR-570-5p
#
# hsa-miR-570-3p
#
# hsa-miR-576-5p
#
# hsa-miR-576-3p
#
# hsa-miR-548a-3p
#
# hsa-miR-548b-5p
#
# hsa-miR-590-3p
#
# hsa-miR-548a-5p
#
# hsa-miR-603
#
# hsa-miR-604
#
# hsa-miR-548c-5p
#
# hsa-miR-548c-3p
#
# hsa-miR-548d-5p
#
# hsa-miR-421
#
# hsa-miR-766-5p
#
# hsa-miR-759
#
# hsa-miR-876-3p
#
# hsa-miR-208b-5p
#
# hsa-miR-944
#
# hsa-miR-548j-5p
#
# hsa-miR-1297
#
# hsa-miR-1299
#
# ...
